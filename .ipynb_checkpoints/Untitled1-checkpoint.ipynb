# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ashok/Downloads/world_happiness.csv")
df
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.tail(2)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 2197                            54.050                         0.668
# 2198                            54.525                         0.652
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 2197      -0.076                      0.757            0.610            0.242
# 2198      -0.070                      0.753            0.641            0.191

# %%
df.shape
# Out:
# (2199, 11)

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
renamed_columns = {i:'_'.join(i.split(' ')).lower() for i in df.columns}  #here we are renaming the column name into the names having _ instead of the space
df.rename(columns=renamed_columns,inplace=True)  #we must use inplace inorder to update the current existing df 
df
# Out:
#      country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018        3.616               7.783           0.775
# 2195     Zimbabwe  2019        2.694               7.698           0.759
# 2196     Zimbabwe  2020        3.160               7.596           0.717
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# ...

# %%
df.dtypes
# Out:
# Country name                         object
# year                                  int64
# Life Ladder                         float64
# Log GDP per capita                  float64
# Social support                      float64
# Healthy life expectancy at birth    float64
# Freedom to make life choices        float64
# Generosity                          float64
# Perceptions of corruption           float64
# Positive affect                     float64
# Negative affect                     float64
# dtype: object

# %%
float_columns = [i for i in df.columns if i not in ['country_name','year']]
float_columns
df.astype({i:float for i in float_columns}) #here we are converting the type of the data inside the float_columns into float type
# Out:
#      country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018        3.616               7.783           0.775
# 2195     Zimbabwe  2019        2.694               7.698           0.759
# 2196     Zimbabwe  2020        3.160               7.596           0.717
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# ...

# %%
df.describe()  #this gives us the statistical data of all the numeric columns data
# Out:
#               year  life_ladder  log_gdp_per_capita  social_support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479227            9.389760        0.810681
# std       4.718736     1.125527            1.153402        0.120953
# min    2005.000000     1.281000            5.527000        0.228000
# 25%    2010.000000     4.647000            8.500000        0.747000
# 50%    2014.000000     5.432000            9.499000        0.836000
# 75%    2018.000000     6.309500           10.373500        0.905000
# max    2022.000000     8.019000           11.664000        0.987000
#
#        healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294582                      0.747847
# std                            6.901104                      0.140137
# min                            6.720000                      0.258000
# ...

# %%
df[['life_ladder']]
# Out:
#       life_ladder
# 0           3.724
# 1           4.402
# 2           4.758
# 3           3.832
# 4           3.783
# ...           ...
# 2194        3.616
# 2195        2.694
# 2196        3.160
# 2197        3.155
# 2198        3.296
#
# [2199 rows x 1 columns]

# %%
zimbabwe_df = df[df['country_name'].str.lower()=='zimbabwe']
zimbabwe_df.reset_index(drop=True) #here we are resetting the index of the dataframe where the country_name is zimbabwe
# Out:
#    country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0      Zimbabwe  2006        3.826               7.460           0.822
# 1      Zimbabwe  2007        3.280               7.413           0.828
# 2      Zimbabwe  2008        3.174               7.210           0.843
# 3      Zimbabwe  2009        4.056               7.313           0.806
# 4      Zimbabwe  2010        4.682               7.495           0.857
# 5      Zimbabwe  2011        4.846               7.617           0.865
# 6      Zimbabwe  2012        4.955               7.745           0.896
# 7      Zimbabwe  2013        4.690               7.755           0.799
# 8      Zimbabwe  2014        4.184               7.748           0.766
# 9      Zimbabwe  2015        3.703               7.747           0.736
# 10     Zimbabwe  2016        3.735               7.735           0.768
# 11     Zimbabwe  2017        3.638               7.754           0.754
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind='scatter',x='log_gdp_per_capita',y='life_ladder')
# Out:
# <Axes: xlabel='log_gdp_per_capita', ylabel='life_ladder'>

# %%
color_dict = {
    'Brazil':'green',
    'India':'blue',
    'Nepal':'red'
}
#here we are doing scatter plot with the country's gdp and life ladder, representing visually based on the color
df.plot(kind='scatter',x='log_gdp_per_capita',y='life_ladder',c=[color_dict.get(c,'yellow') for c in df.country_name])
# Out:
# <Axes: xlabel='log_gdp_per_capita', ylabel='life_ladder'>

# %%
df.hist('life_ladder')  #histogram based on the life_ladder
# Out:
# array([[<Axes: title={'center': 'life_ladder'}>]], dtype=object)
